# %%
import warnings 
warnings.simplefilter('ignore')

import scanpy as sc
import scparadise
import muon as mu
import pandas as pd
import os

# %%
# Load normalized integrated data
mdata = mu.read_h5mu('Heart_3p_CITE/mdata_unintegrated_annotated.h5mu')

# %%
# Select RNA modality from MuData object (mdata)
mdata = mdata[mdata.obs['celltype_l2'] != 'classical DC1']
mdata = mdata[mdata.obs['celltype_l2'] != 'Neutrophil']
mdata = mdata[mdata.obs['celltype_l2'] != 'plasmacytoid DC']
mdata = mdata[mdata.obs['celltype_l2'] != 'ILC']
mdata = mdata[mdata.obs['celltype_l2'] != 'proliferating T']
adata = mdata.mod['rna'].copy()
del mdata

# %%
# Subset anndata object based on a selected marker genes
genes = pd.read_csv('Heart_3p_CITE/genes_for_AI.csv')
adata = adata[:, genes.genes].copy()

# %%
# Create list of samples to leave in reference train dataset
lst_reference = [12, 13, 17, 27, 28, 29, 30, 32, 39, 42]

# %%
# Create adata_train - 8 samples of 8 donors from unintegrated adata object (8 donors, 24 samples)
adata_train = adata[adata.obs['orig.ident'].isin(lst_reference)].copy()

# %%
# Balance dataset based on l3 annotation level
adata_balanced = scparadise.scnoah.balance(adata_train, 
                                           sample='orig.ident',
                                           celltype_l1='celltype_l1',
                                           celltype_l2='celltype_l2')
# Out:
# Successfully undersampled cell types: Capillary endothelial, Macrophage, Arterial endothelial, SMC, Pericyte, APOD+ fibroblast, CD55+ fibroblast
#
# Successfully oversampled cell types: Venous endothelial, POSTN+FAP+ fibroblast, classical DC2, Myofibroblast, CD4+ T, CD8+ T, CD16+ Mono, ATF5+ fibroblast, NK CD56dim, Muscle, Neuron, Mast, Lymphatic endothelial, proliferating myeloid, NK CD56bright

# %%
# Train scadam model using adata_balanced dataset
scparadise.scadam.train(adata_balanced,
                        path = '',
                        model_name = 'model_Heart_scAdam_default',
                        celltype_l1 = 'celltype_l1',
                        celltype_l2 = 'celltype_l2',
                        eval_metric = ['balanced_accuracy','accuracy'])
# Out:
# Successfully saved genes names for training model
#
# Successfully saved dictionary of dataset annotations
#
# Train dataset contains: 57835 cells, it is 90.0 % of input dataset
# Test dataset contains: 6427 cells, it is 10.0 % of input dataset
#
# Accelerator: cuda
# Start training
# epoch 0  | loss: 2.09136 | train_balanced_accuracy: 0.47135 | train_accuracy: 0.57    | valid_balanced_accuracy: 0.46828 | valid_accuracy: 0.56675 |  0:00:03s
# epoch 1  | loss: 0.98051 | train_balanced_accuracy: 0.76756 | train_accuracy: 0.78597 | valid_balanced_accuracy: 0.76807 | valid_accuracy: 0.78684 |  0:00:05s
# epoch 2  | loss: 0.68525 | train_balanced_accuracy: 0.83105 | train_accuracy: 0.84126 | valid_balanced_accuracy: 0.82627 | valid_accuracy: 0.83709 |  0:00:08s
# epoch 3  | loss: 0.58466 | train_balanced_accuracy: 0.86852 | train_accuracy: 0.87379 | valid_balanced_accuracy: 0.86547 | valid_accuracy: 0.87062 |  0:00:11s
# epoch 4  | loss: 0.53039 | train_balanced_accuracy: 0.89579 | train_accuracy: 0.8995  | valid_balanced_accuracy: 0.89009 | valid_accuracy: 0.89389 |  0:00:14s
# epoch 5  | loss: 0.49236 | train_balanced_accuracy: 0.90723 | train_accuracy: 0.91085 | valid_balanced_accuracy: 0.9008  | valid_accuracy: 0.90415 |  0:00:17s
# epoch 6  | loss: 0.46631 | train_balanced_accuracy: 0.91826 | train_accuracy: 0.92059 | valid_balanced_accuracy: 0.91123 | valid_accuracy: 0.91427 |  0:00:20s
# epoch 7  | loss: 0.44249 | train_balanced_accuracy: 0.91972 | train_accuracy: 0.92192 | valid_balanced_accuracy: 0.91432 | valid_accuracy: 0.91645 |  0:00:23s
# epoch 8  | loss: 0.43529 | train_balanced_accuracy: 0.93053 | train_accuracy: 0.93248 | valid_balanced_accuracy: 0.92543 | valid_accuracy: 0.92718 |  0:00:26s
# epoch 9  | loss: 0.41586 | train_balanced_accuracy: 0.93056 | train_accuracy: 0.93264 | valid_balanced_accuracy: 0.92557 | valid_accuracy: 0.92765 |  0:00:29s
# epoch 10 | loss: 0.40949 | train_balanced_accuracy: 0.93742 | train_accuracy: 0.93897 | valid_balanced_accuracy: 0.93091 | valid_accuracy: 0.93247 |  0:00:32s
# epoch 11 | loss: 0.39399 | train_balanced_accuracy: 0.94031 | train_accuracy: 0.94179 | valid_balanced_accuracy: 0.93192 | valid_accuracy: 0.93364 |  0:00:35s
# epoch 12 | loss: 0.38167 | train_balanced_accuracy: 0.9424  | train_accuracy: 0.94355 | valid_balanced_accuracy: 0.93372 | valid_accuracy: 0.93473 |  0:00:38s
# epoch 13 | loss: 0.38077 | train_balanced_accuracy: 0.9429  | train_accuracy: 0.94431 | valid_balanced_accuracy: 0.9327  | valid_accuracy: 0.93434 |  0:00:41s
# epoch 14 | loss: 0.367   | train_balanced_accuracy: 0.94937 | train_accuracy: 0.95039 | valid_balanced_accuracy: 0.9386  | valid_accuracy: 0.9401  |  0:00:44s
# epoch 15 | loss: 0.36318 | train_balanced_accuracy: 0.9505  | train_accuracy: 0.95157 | valid_balanced_accuracy: 0.93751 | valid_accuracy: 0.93924 |  0:00:47s
# epoch 16 | loss: 0.35639 | train_balanced_accuracy: 0.95133 | train_accuracy: 0.95191 | valid_balanced_accuracy: 0.93553 | valid_accuracy: 0.93652 |  0:00:50s
# epoch 17 | loss: 0.35023 | train_balanced_accuracy: 0.95079 | train_accuracy: 0.95163 | valid_balanced_accuracy: 0.93902 | valid_accuracy: 0.94033 |  0:00:53s
# epoch 18 | loss: 0.34456 | train_balanced_accuracy: 0.95331 | train_accuracy: 0.9541  | valid_balanced_accuracy: 0.9404  | valid_accuracy: 0.94173 |  0:00:57s
# epoch 19 | loss: 0.34218 | train_balanced_accuracy: 0.95375 | train_accuracy: 0.95471 | valid_balanced_accuracy: 0.93938 | valid_accuracy: 0.94095 |  0:01:03s
# epoch 20 | loss: 0.33998 | train_balanced_accuracy: 0.95419 | train_accuracy: 0.95503 | valid_balanced_accuracy: 0.94104 | valid_accuracy: 0.94196 |  0:01:10s
# epoch 21 | loss: 0.33537 | train_balanced_accuracy: 0.95657 | train_accuracy: 0.95732 | valid_balanced_accuracy: 0.94377 | valid_accuracy: 0.94484 |  0:01:15s
# epoch 22 | loss: 0.32983 | train_balanced_accuracy: 0.95801 | train_accuracy: 0.95863 | valid_balanced_accuracy: 0.94416 | valid_accuracy: 0.94515 |  0:01:19s
# epoch 23 | loss: 0.32719 | train_balanced_accuracy: 0.9596  | train_accuracy: 0.96007 | valid_balanced_accuracy: 0.94535 | valid_accuracy: 0.94593 |  0:01:22s
# epoch 24 | loss: 0.32712 | train_balanced_accuracy: 0.95829 | train_accuracy: 0.959   | valid_balanced_accuracy: 0.94553 | valid_accuracy: 0.94671 |  0:01:25s
# epoch 25 | loss: 0.32262 | train_balanced_accuracy: 0.95742 | train_accuracy: 0.95819 | valid_balanced_accuracy: 0.9431  | valid_accuracy: 0.94414 |  0:01:28s
# epoch 26 | loss: 0.32324 | train_balanced_accuracy: 0.96043 | train_accuracy: 0.96106 | valid_balanced_accuracy: 0.94189 | valid_accuracy: 0.94313 |  0:01:31s
# epoch 27 | loss: 0.32495 | train_balanced_accuracy: 0.95777 | train_accuracy: 0.95871 | valid_balanced_accuracy: 0.94313 | valid_accuracy: 0.94453 |  0:01:34s
# epoch 28 | loss: 0.32333 | train_balanced_accuracy: 0.95925 | train_accuracy: 0.95968 | valid_balanced_accuracy: 0.94162 | valid_accuracy: 0.94243 |  0:01:37s
# epoch 29 | loss: 0.31453 | train_balanced_accuracy: 0.96157 | train_accuracy: 0.96186 | valid_balanced_accuracy: 0.94496 | valid_accuracy: 0.94593 |  0:01:39s
# epoch 30 | loss: 0.30784 | train_balanced_accuracy: 0.96371 | train_accuracy: 0.96417 | valid_balanced_accuracy: 0.94814 | valid_accuracy: 0.94928 |  0:01:42s
# epoch 31 | loss: 0.30948 | train_balanced_accuracy: 0.96188 | train_accuracy: 0.9624  | valid_balanced_accuracy: 0.94646 | valid_accuracy: 0.94749 |  0:01:45s
# epoch 32 | loss: 0.30591 | train_balanced_accuracy: 0.96267 | train_accuracy: 0.96308 | valid_balanced_accuracy: 0.94707 | valid_accuracy: 0.94803 |  0:01:48s
# epoch 33 | loss: 0.30371 | train_balanced_accuracy: 0.96357 | train_accuracy: 0.96416 | valid_balanced_accuracy: 0.94727 | valid_accuracy: 0.94834 |  0:01:50s
# epoch 34 | loss: 0.30244 | train_balanced_accuracy: 0.96176 | train_accuracy: 0.96251 | valid_balanced_accuracy: 0.94612 | valid_accuracy: 0.9471  |  0:01:53s
# epoch 35 | loss: 0.30376 | train_balanced_accuracy: 0.96497 | train_accuracy: 0.96557 | valid_balanced_accuracy: 0.94672 | valid_accuracy: 0.94827 |  0:01:56s
# epoch 36 | loss: 0.30194 | train_balanced_accuracy: 0.96461 | train_accuracy: 0.96503 | valid_balanced_accuracy: 0.94777 | valid_accuracy: 0.94842 |  0:01:59s
# epoch 37 | loss: 0.30093 | train_balanced_accuracy: 0.96563 | train_accuracy: 0.96599 | valid_balanced_accuracy: 0.95049 | valid_accuracy: 0.95122 |  0:02:02s
# epoch 38 | loss: 0.29931 | train_balanced_accuracy: 0.96563 | train_accuracy: 0.96618 | valid_balanced_accuracy: 0.94937 | valid_accuracy: 0.9506  |  0:02:05s
# epoch 39 | loss: 0.29701 | train_balanced_accuracy: 0.96143 | train_accuracy: 0.96217 | valid_balanced_accuracy: 0.94513 | valid_accuracy: 0.9464  |  0:02:08s
# epoch 40 | loss: 0.30099 | train_balanced_accuracy: 0.9667  | train_accuracy: 0.96706 | valid_balanced_accuracy: 0.94836 | valid_accuracy: 0.94967 |  0:02:11s
# epoch 41 | loss: 0.29368 | train_balanced_accuracy: 0.96572 | train_accuracy: 0.96598 | valid_balanced_accuracy: 0.94926 | valid_accuracy: 0.95005 |  0:02:14s
# epoch 42 | loss: 0.29723 | train_balanced_accuracy: 0.96718 | train_accuracy: 0.96743 | valid_balanced_accuracy: 0.94794 | valid_accuracy: 0.94881 |  0:02:17s
# epoch 43 | loss: 0.29125 | train_balanced_accuracy: 0.96812 | train_accuracy: 0.96847 | valid_balanced_accuracy: 0.95094 | valid_accuracy: 0.95215 |  0:02:20s
# epoch 44 | loss: 0.29379 | train_balanced_accuracy: 0.96759 | train_accuracy: 0.96789 | valid_balanced_accuracy: 0.95018 | valid_accuracy: 0.95107 |  0:02:22s
# epoch 45 | loss: 0.28648 | train_balanced_accuracy: 0.96691 | train_accuracy: 0.9673  | valid_balanced_accuracy: 0.94874 | valid_accuracy: 0.94959 |  0:02:25s
# epoch 46 | loss: 0.28957 | train_balanced_accuracy: 0.96675 | train_accuracy: 0.96685 | valid_balanced_accuracy: 0.94941 | valid_accuracy: 0.95005 |  0:02:28s
# epoch 47 | loss: 0.29232 | train_balanced_accuracy: 0.9674  | train_accuracy: 0.96795 | valid_balanced_accuracy: 0.95091 | valid_accuracy: 0.95208 |  0:02:31s
# epoch 48 | loss: 0.28286 | train_balanced_accuracy: 0.96687 | train_accuracy: 0.96715 | valid_balanced_accuracy: 0.94915 | valid_accuracy: 0.95029 |  0:02:34s
# epoch 49 | loss: 0.28964 | train_balanced_accuracy: 0.96968 | train_accuracy: 0.97003 | valid_balanced_accuracy: 0.95159 | valid_accuracy: 0.95262 |  0:02:37s
# epoch 50 | loss: 0.28817 | train_balanced_accuracy: 0.96905 | train_accuracy: 0.96936 | valid_balanced_accuracy: 0.95105 | valid_accuracy: 0.95231 |  0:02:40s
# epoch 51 | loss: 0.27808 | train_balanced_accuracy: 0.96875 | train_accuracy: 0.96909 | valid_balanced_accuracy: 0.94972 | valid_accuracy: 0.95091 |  0:02:43s
# epoch 52 | loss: 0.28131 | train_balanced_accuracy: 0.96924 | train_accuracy: 0.96955 | valid_balanced_accuracy: 0.95054 | valid_accuracy: 0.95145 |  0:02:46s
# epoch 53 | loss: 0.286   | train_balanced_accuracy: 0.96936 | train_accuracy: 0.96973 | valid_balanced_accuracy: 0.9516  | valid_accuracy: 0.95254 |  0:02:48s
# epoch 54 | loss: 0.27697 | train_balanced_accuracy: 0.9694  | train_accuracy: 0.96972 | valid_balanced_accuracy: 0.95188 | valid_accuracy: 0.95293 |  0:02:51s
# epoch 55 | loss: 0.28424 | train_balanced_accuracy: 0.9695  | train_accuracy: 0.96978 | valid_balanced_accuracy: 0.95135 | valid_accuracy: 0.95231 |  0:02:54s
# epoch 56 | loss: 0.28074 | train_balanced_accuracy: 0.96915 | train_accuracy: 0.96935 | valid_balanced_accuracy: 0.94921 | valid_accuracy: 0.95013 |  0:02:56s
# epoch 57 | loss: 0.2837  | train_balanced_accuracy: 0.9696  | train_accuracy: 0.96987 | valid_balanced_accuracy: 0.95277 | valid_accuracy: 0.95356 |  0:02:59s
# epoch 58 | loss: 0.28416 | train_balanced_accuracy: 0.96811 | train_accuracy: 0.96851 | valid_balanced_accuracy: 0.94856 | valid_accuracy: 0.94943 |  0:03:02s
# epoch 59 | loss: 0.2809  | train_balanced_accuracy: 0.97088 | train_accuracy: 0.97131 | valid_balanced_accuracy: 0.95299 | valid_accuracy: 0.95433 |  0:03:05s
# epoch 60 | loss: 0.27811 | train_balanced_accuracy: 0.97022 | train_accuracy: 0.97048 | valid_balanced_accuracy: 0.95113 | valid_accuracy: 0.95208 |  0:03:08s
# epoch 61 | loss: 0.27956 | train_balanced_accuracy: 0.97111 | train_accuracy: 0.9714  | valid_balanced_accuracy: 0.95321 | valid_accuracy: 0.95418 |  0:03:11s
# epoch 62 | loss: 0.27344 | train_balanced_accuracy: 0.96954 | train_accuracy: 0.96987 | valid_balanced_accuracy: 0.95417 | valid_accuracy: 0.95503 |  0:03:14s
# epoch 63 | loss: 0.27643 | train_balanced_accuracy: 0.97037 | train_accuracy: 0.9706  | valid_balanced_accuracy: 0.95267 | valid_accuracy: 0.9534  |  0:03:17s
# epoch 64 | loss: 0.28001 | train_balanced_accuracy: 0.96887 | train_accuracy: 0.96915 | valid_balanced_accuracy: 0.94779 | valid_accuracy: 0.94889 |  0:03:20s
# epoch 65 | loss: 0.27596 | train_balanced_accuracy: 0.97162 | train_accuracy: 0.97196 | valid_balanced_accuracy: 0.95076 | valid_accuracy: 0.95208 |  0:03:23s
# epoch 66 | loss: 0.27634 | train_balanced_accuracy: 0.97106 | train_accuracy: 0.97134 | valid_balanced_accuracy: 0.95161 | valid_accuracy: 0.95247 |  0:03:26s
# epoch 67 | loss: 0.27622 | train_balanced_accuracy: 0.96941 | train_accuracy: 0.96969 | valid_balanced_accuracy: 0.95163 | valid_accuracy: 0.95247 |  0:03:28s
# epoch 68 | loss: 0.27095 | train_balanced_accuracy: 0.97023 | train_accuracy: 0.97053 | valid_balanced_accuracy: 0.95258 | valid_accuracy: 0.95356 |  0:03:31s
# epoch 69 | loss: 0.27479 | train_balanced_accuracy: 0.97122 | train_accuracy: 0.97138 | valid_balanced_accuracy: 0.95296 | valid_accuracy: 0.95356 |  0:03:34s
# epoch 70 | loss: 0.26786 | train_balanced_accuracy: 0.97286 | train_accuracy: 0.97329 | valid_balanced_accuracy: 0.95231 | valid_accuracy: 0.95363 |  0:03:37s
# epoch 71 | loss: 0.27421 | train_balanced_accuracy: 0.97104 | train_accuracy: 0.97119 | valid_balanced_accuracy: 0.95068 | valid_accuracy: 0.95145 |  0:03:40s
# epoch 72 | loss: 0.27493 | train_balanced_accuracy: 0.97188 | train_accuracy: 0.97227 | valid_balanced_accuracy: 0.95335 | valid_accuracy: 0.95464 |  0:03:43s
#
# Early stopping occurred at epoch 72 with best_epoch = 62 and best_valid_accuracy = 0.95503
#
# Successfully saved training history and parameters
# Successfully saved model at model_Heart_scAdam_default/model.zip

# %%
# Create lists with test samples
lst_test_1 = ['1_6', '2_7', '4_5', '8_9']
lst_test_2 = ['41', '34', '15', '33']

# %%
for folder in lst_test_1:
    os.makedirs(os.path.join('Heart_3p_CITE/reports_model_Heart_scAdam_default', folder))
    adata_test = adata[adata.obs['orig.ident'].isin([int(folder[0]), int(folder[2])])].copy()
    # Predict annotation levels using pretrained scadam model
    adata_test = scparadise.scadam.predict(adata_test, 
                                           path_model = 'model_Heart_scAdam_default')
    # Create and save classification report of annotation levels
    scparadise.scnoah.report_classif_full(adata_test, 
                                          celltype = 'celltype_l1', 
                                          pred_celltype = 'pred_celltype_l1', 
                                          report_name = 'report_test_model_scAdam_default_celltype_l1.csv',
                                          save_path = os.path.join('Heart_3p_CITE/reports_model_Heart_scAdam_default', folder).replace("\\","/"),
                                          save_report = True)
    scparadise.scnoah.report_classif_full(adata_test, 
                                          celltype = 'celltype_l2', 
                                          pred_celltype = 'pred_celltype_l2', 
                                          report_name = 'report_test_model_scAdam_default_celltype_l2.csv',
                                          save_path = os.path.join('Heart_3p_CITE/reports_model_Heart_scAdam_default', folder).replace("\\","/"),
                                          save_report = True)
for folder in lst_test_2:
    os.makedirs(os.path.join('Heart_3p_CITE/reports_model_Heart_scAdam_default', folder))
    adata_test = adata[adata.obs['orig.ident'].isin([int(folder)])].copy()
    # Predict annotation levels using pretrained scadam model
    adata_test = scparadise.scadam.predict(adata_test, 
                                           path_model = 'model_Heart_scAdam_default')
    # Create and save classification report of annotation levels
    scparadise.scnoah.report_classif_full(adata_test, 
                                          celltype = 'celltype_l1', 
                                          pred_celltype = 'pred_celltype_l1', 
                                          report_name = 'report_test_model_scAdam_default_celltype_l1.csv',
                                          save_path = os.path.join('Heart_3p_CITE/reports_model_Heart_scAdam_default', folder).replace("\\","/"),
                                          save_report = True)
    scparadise.scnoah.report_classif_full(adata_test, 
                                          celltype = 'celltype_l2', 
                                          pred_celltype = 'pred_celltype_l2', 
                                          report_name = 'report_test_model_scAdam_default_celltype_l2.csv',
                                          save_path = os.path.join('Heart_3p_CITE/reports_model_Heart_scAdam_default', folder).replace("\\","/"),
                                          save_report = True)
# Out:
# Successfully loaded list of genes used for training model
#
# Successfully loaded dictionary of dataset annotations
#
# Successfully loaded model
#
# Successfully added predicted celltype_l1 and cell type probabilities
# Successfully added predicted celltype_l2 and cell type probabilities
# Successfully saved report
#
# Successfully saved report
#
# Successfully loaded list of genes used for training model
#
# Successfully loaded dictionary of dataset annotations
#
# Successfully loaded model
#
# Successfully added predicted celltype_l1 and cell type probabilities
# Successfully added predicted celltype_l2 and cell type probabilities
# Successfully saved report
#
# Successfully saved report
#
# Successfully loaded list of genes used for training model
#
# Successfully loaded dictionary of dataset annotations
#
# Successfully loaded model
#
# Successfully added predicted celltype_l1 and cell type probabilities
# Successfully added predicted celltype_l2 and cell type probabilities
# Successfully saved report
#
# Successfully saved report
#
# Successfully loaded list of genes used for training model
#
# Successfully loaded dictionary of dataset annotations
#
# Successfully loaded model
#
# Successfully added predicted celltype_l1 and cell type probabilities
# Successfully added predicted celltype_l2 and cell type probabilities
# Successfully saved report
#
# Successfully saved report
#
# Successfully loaded list of genes used for training model
#
# Successfully loaded dictionary of dataset annotations
#
# Successfully loaded model
#
# Successfully added predicted celltype_l1 and cell type probabilities
# Successfully added predicted celltype_l2 and cell type probabilities
# Successfully saved report
#
# Successfully saved report
#
# Successfully loaded list of genes used for training model
#
# Successfully loaded dictionary of dataset annotations
#
# Successfully loaded model
#
# Successfully added predicted celltype_l1 and cell type probabilities
# Successfully added predicted celltype_l2 and cell type probabilities
# Successfully saved report
#
# Successfully saved report
#
# Successfully loaded list of genes used for training model
#
# Successfully loaded dictionary of dataset annotations
#
# Successfully loaded model
#
# Successfully added predicted celltype_l1 and cell type probabilities
# Successfully added predicted celltype_l2 and cell type probabilities
# Successfully saved report
#
# Successfully saved report
#
# Successfully loaded list of genes used for training model
#
# Successfully loaded dictionary of dataset annotations
#
# Successfully loaded model
#
# Successfully added predicted celltype_l1 and cell type probabilities
# Successfully added predicted celltype_l2 and cell type probabilities
# Successfully saved report
#
# Successfully saved report

# %%
import session_info
session_info.show()
# Out:
# <details>
# <summary>Click to view session information</summary>
# <pre>
# -----
# anndata             0.10.8
# muon                0.1.6
# pandas              2.2.3
# scanpy              1.10.3
# scparadise          0.3.2_beta
# session_info        1.0.0
# -----
# </pre>
# <details>
# <summary>Click to view modules imported as dependencies</summary>
# <pre>
# PIL                         10.4.0
# alembic                     1.13.3
# anyio                       NA
# arrow                       1.3.0
# asciitree                   NA
# asttokens                   NA
# attr                        24.2.0
# attrs                       24.2.0
# awkward                     2.7.1
# awkward_cpp                 NA
# babel                       2.16.0
# backports                   NA
# certifi                     2024.08.30
# cffi                        1.17.1
# charset_normalizer          3.3.2
# cloudpickle                 3.1.0
# colorlog                    NA
# comm                        0.2.2
# cycler                      0.12.1
# cython_runtime              NA
# dask                        2024.8.0
# dateutil                    2.9.0.post0
# debugpy                     1.8.6
# decorator                   5.1.1
# defusedxml                  0.7.1
# exceptiongroup              1.2.2
# executing                   2.1.0
# fastjsonschema              NA
# fqdn                        NA
# fsspec                      2023.6.0
# greenlet                    3.1.1
# h5py                        3.12.1
# idna                        3.10
# igraph                      0.11.6
# imblearn                    0.12.3
# importlib_metadata          NA
# importlib_resources         NA
# ipykernel                   6.29.5
# isoduration                 NA
# jaraco                      NA
# jedi                        0.19.1
# jinja2                      3.1.4
# joblib                      1.4.2
# json5                       0.9.25
# jsonpointer                 3.0.0
# jsonschema                  4.23.0
# jsonschema_specifications   NA
# jupyter_events              0.10.0
# jupyter_server              2.14.2
# jupyterlab_server           2.27.3
# kiwisolver                  1.4.7
# legacy_api_wrap             NA
# leidenalg                   0.10.2
# llvmlite                    0.43.0
# mako                        1.3.5
# markupsafe                  2.1.5
# matplotlib                  3.9.2
# more_itertools              10.5.0
# mpl_toolkits                NA
# mpmath                      1.3.0
# msgpack                     1.1.0
# mudata                      0.2.4
# natsort                     8.4.0
# nbformat                    5.10.4
# numba                       0.60.0
# numcodecs                   0.12.1
# numpy                       1.25.0
# optuna                      4.0.0
# overrides                   NA
# packaging                   24.1
# parso                       0.8.4
# patsy                       0.5.6
# pexpect                     4.9.0
# platformdirs                4.3.6
# plotly                      5.24.1
# prometheus_client           NA
# prompt_toolkit              3.0.48
# psutil                      6.0.0
# ptyprocess                  0.7.0
# pure_eval                   0.2.3
# pyarrow                     18.1.0
# pycparser                   2.22
# pydev_ipython               NA
# pydevconsole                NA
# pydevd                      3.1.0
# pydevd_file_utils           NA
# pydevd_plugins              NA
# pydevd_tracing              NA
# pydot                       3.0.3
# pygments                    2.18.0
# pynndescent                 0.5.13
# pyparsing                   3.1.4
# pythonjsonlogger            NA
# pytorch_tabnet              NA
# pytz                        2024.2
# referencing                 NA
# requests                    2.32.3
# rfc3339_validator           0.1.4
# rfc3986_validator           0.1.1
# rich                        NA
# rpds                        NA
# scipy                       1.13.1
# seaborn                     0.13.2
# send2trash                  NA
# setuptools                  75.1.0
# setuptools_scm              NA
# shap                        0.46.0
# six                         1.16.0
# sklearn                     1.5.2
# slicer                      NA
# sniffio                     1.3.1
# sqlalchemy                  2.0.35
# stack_data                  0.6.3
# statsmodels                 0.14.3
# sympy                       1.13.3
# tblib                       3.0.0
# texttable                   1.7.0
# threadpoolctl               3.5.0
# tlz                         0.12.1
# tomli                       2.0.1
# toolz                       0.12.1
# torch                       2.4.1+cu121
# torchgen                    NA
# tornado                     6.4.1
# tqdm                        4.66.5
# traitlets                   5.14.3
# triton                      3.0.0
# typing_extensions           NA
# umap                        0.5.6
# uri_template                NA
# urllib3                     1.26.20
# wcwidth                     0.2.13
# webcolors                   24.8.0
# websocket                   1.8.0
# yaml                        6.0.2
# zarr                        2.18.2
# zipp                        NA
# zmq                         26.2.0
# zoneinfo                    NA
# </pre>
# </details> <!-- seems like this ends pre, so might as well be explicit -->
# <pre>
# -----
# IPython             8.18.1
# jupyter_client      8.6.3
# jupyter_core        5.7.2
# jupyterlab          4.2.5
# -----
# Python 3.9.19 (main, May  6 2024, 19:43:03) [GCC 11.2.0]
# Linux-5.15.167.4-microsoft-standard-WSL2-x86_64-with-glibc2.35
# -----
# Session information updated at 2025-01-23 10:58
# </pre>
# </details>
