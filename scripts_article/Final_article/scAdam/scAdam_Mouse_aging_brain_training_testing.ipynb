# %%
import warnings 
warnings.simplefilter('ignore')

import scanpy as sc
import scparadise
import pandas as pd
import numpy as np
from scipy.sparse import csc_matrix
import scvi
import pandas as pd
import os

# %%
adata = sc.read_text('Mouse_aging_brain/exprMatrix.tsv.gz')
adata = adata.T
adata.X = csc_matrix(adata.X, dtype=np.float32)
meta = pd.read_csv('Mouse_aging_brain/meta.tsv', sep='\t', index_col = 0)
adata.obs = meta
adata.raw = adata

# %%
# Find marker genes of cell types
sc.tl.rank_genes_groups(adata, 
                        groupby='Celltype',
                        method='t-test_overestim_var', pts = True)

# %%
# Filter marker genes of cell types
sc.tl.filter_rank_genes_groups(adata, 
                               min_fold_change=1.0, 
                               min_in_group_fraction=0.4,
                               key_added='filtered_rank_genes_groups')

# %%
# Create list of genes for model training
lst_l1 = []
for i in adata.obs['Celltype'].unique():
    df = sc.get.rank_genes_groups_df(adata, group = i, key='filtered_rank_genes_groups', pval_cutoff=0.05)
    df['pts_comparizon'] = df['pct_nz_group']/df['pct_nz_reference']
    lst_l1.extend(df.sort_values(by='logfoldchanges', ascending=False).head(50)['names'].tolist())
    lst_l1.extend(df.sort_values(by='pts_comparizon', ascending=False).head(50)['names'].tolist())
lst_l1 = np.unique(lst_l1).tolist()

# %%
del adata.uns['filtered_rank_genes_groups']
adata.write_h5ad('Mouse_aging_brain/adata_unintegrated.h5ad')

# %%
# Save genes for models training
pd.DataFrame(lst_l1, columns = ['genes']).sample(frac=1, random_state=42).to_csv('Mouse_aging_brain/genes_for_AI.csv', index=False, header=True)

# %%
# Subset genes
genes = pd.read_csv('Mouse_aging_brain/genes_for_AI.csv')
adata = adata[:, genes.genes].copy()

# %%
# Create list of reference samples
lst_reference = ['old1', 'oldex1', 'oldex2', 'young2']

# %%
# Create adata_train dataset for model training
adata_train = adata[adata.obs['orig.ident'].isin(lst_reference)].copy()

# %%
# Balance dataset
adata_balanced = scparadise.scnoah.balance(adata_train, 
                                           sample='orig.ident',
                                           celltype_l1='Celltype')
# Out:
# Successfully undersampled cell types: EC, MG, AC
#
# Successfully oversampled cell types: SMC, CPC, OPC, PC, MAC, EPC, imNeur, OLG, mNeur, TNC, MNC, NRP, Hb_EC

# %%
# Train scadam model using adata_balanced dataset
scparadise.scadam.train(adata_balanced,
                        path='',
                        model_name='Mouse_aging_brain_scAdam',
                        celltype_l1='celltype_l1',
                        eval_metric=['balanced_accuracy','accuracy'])
# Out:
# Successfully saved genes names for training model
#
# Successfully saved dictionary of dataset annotations
#
# Train dataset contains: 24336 cells, it is 90.0 % of input dataset
# Test dataset contains: 2704 cells, it is 10.0 % of input dataset
#
# Accelerator: cuda
# Start training
# epoch 0  | loss: 2.82444 | train_balanced_accuracy: 0.21294 | train_accuracy: 0.21294 | valid_balanced_accuracy: 0.22189 | valid_accuracy: 0.22189 |  0:00:01s
# epoch 33 | loss: 0.21807 | train_balanced_accuracy: 0.99741 | train_accuracy: 0.99741 | valid_balanced_accuracy: 0.99408 | valid_accuracy: 0.99408 |  0:00:39s
# epoch 34 | loss: 0.21997 | train_balanced_accuracy: 0.99778 | train_accuracy: 0.99778 | valid_balanced_accuracy: 0.9926  | valid_accuracy: 0.9926  |  0:00:40s
# epoch 35 | loss: 0.2174  | train_balanced_accuracy: 0.99819 | train_accuracy: 0.99819 | valid_balanced_accuracy: 0.99371 | valid_accuracy: 0.99371 |  0:00:42s
# epoch 36 | loss: 0.2171  | train_balanced_accuracy: 0.99823 | train_accuracy: 0.99823 | valid_balanced_accuracy: 0.99371 | valid_accuracy: 0.99371 |  0:00:43s
# epoch 37 | loss: 0.21578 | train_balanced_accuracy: 0.99844 | train_accuracy: 0.99844 | valid_balanced_accuracy: 0.99371 | valid_accuracy: 0.99371 |  0:00:44s
# epoch 38 | loss: 0.20885 | train_balanced_accuracy: 0.99856 | train_accuracy: 0.99856 | valid_balanced_accuracy: 0.9926  | valid_accuracy: 0.9926  |  0:00:45s
# epoch 39 | loss: 0.21984 | train_balanced_accuracy: 0.99832 | train_accuracy: 0.99832 | valid_balanced_accuracy: 0.99223 | valid_accuracy: 0.99223 |  0:00:46s
# epoch 40 | loss: 0.21177 | train_balanced_accuracy: 0.99819 | train_accuracy: 0.99819 | valid_balanced_accuracy: 0.99186 | valid_accuracy: 0.99186 |  0:00:48s
# epoch 41 | loss: 0.20741 | train_balanced_accuracy: 0.99852 | train_accuracy: 0.99852 | valid_balanced_accuracy: 0.99149 | valid_accuracy: 0.99149 |  0:00:49s
# epoch 42 | loss: 0.20548 | train_balanced_accuracy: 0.99869 | train_accuracy: 0.99869 | valid_balanced_accuracy: 0.99038 | valid_accuracy: 0.99038 |  0:00:50s
# epoch 43 | loss: 0.19877 | train_balanced_accuracy: 0.99897 | train_accuracy: 0.99897 | valid_balanced_accuracy: 0.9926  | valid_accuracy: 0.9926  |  0:00:52s
#
# Early stopping occurred at epoch 43 with best_epoch = 33 and best_valid_accuracy = 0.99408
#
# Successfully saved training history and parameters
# Successfully saved model at Mouse_aging_brain_scAdam/model.zip

# %%
# Create list of test datasets
lst_test = ['young4', 'old2', 'old4', 'young1', 'oldex4']

# %%
for folder in lst_test:
    os.makedirs(os.path.join('Mouse_aging_brain/reports_model_Mouse_brain_scAdam_default', folder))
    adata_test = adata[adata.obs['orig.ident'].isin([folder])].copy()
    # Predict annotation levels using pretrained scadam model
    adata_test = scparadise.scadam.predict(adata_test, 
                                           path_model = 'Mouse_aging_brain_scAdam')
    # Create and save classification report of annotation levels
    scparadise.scnoah.report_classif_full(adata_test, 
                                          celltype = 'Celltype', 
                                          pred_celltype = 'pred_celltype_l1', 
                                          report_name = 'report_test_model_scAdam_default_celltype_l1.csv',
                                          save_path = os.path.join('Mouse_aging_brain/reports_model_Mouse_brain_scAdam_default', folder).replace("\\","/"),
                                          save_report = True)
# Out:
# Successfully loaded list of genes used for training model
#
# Successfully loaded dictionary of dataset annotations
#
# Successfully loaded model
#
# Successfully added predicted celltype_l1 and cell type probabilities
# Successfully saved report
#
# Successfully loaded list of genes used for training model
#
# Successfully loaded dictionary of dataset annotations
#
# Successfully loaded model
#
# Successfully added predicted celltype_l1 and cell type probabilities
# Successfully saved report
#
# Successfully loaded list of genes used for training model
#
# Successfully loaded dictionary of dataset annotations
#
# Successfully loaded model
#
# Successfully added predicted celltype_l1 and cell type probabilities
# Successfully saved report
#
# Successfully loaded list of genes used for training model
#
# Successfully loaded dictionary of dataset annotations
#
# Successfully loaded model
#
# Successfully added predicted celltype_l1 and cell type probabilities
# Successfully saved report
#
# Successfully loaded list of genes used for training model
#
# Successfully loaded dictionary of dataset annotations
#
# Successfully loaded model
#
# Successfully added predicted celltype_l1 and cell type probabilities
# Successfully saved report

# %%
pip list
# Out:
# Package                   Version
# ------------------------- --------------
# absl-py                   2.1.0
# adjustText                1.3.0
# aiobotocore               2.5.4
# aiohappyeyeballs          2.4.2
# aiohttp                   3.8.4
# aioitertools              0.12.0
# aiosignal                 1.3.1
# airr                      1.5.1
# alembic                   1.13.3
# anndata                   0.9.1
# annoy                     1.17.3
# anyio                     3.6.2
# appdirs                   1.4.4
# argon2-cffi               23.1.0
# argon2-cffi-bindings      21.2.0
# array_api_compat          1.8
# arrow                     1.2.3
# asciitree                 0.3.3
# asttokens                 2.4.1
# async-lru                 2.0.4
# async-timeout             4.0.2
# attrs                     23.1.0
# awkward                   2.7.1
# awkward_cpp               42
# babel                     2.16.0
# bamnostic                 1.1.10
# bbknn                     1.6.0
# bcrypt                    4.2.1
# beautifulsoup4            4.12.2
# bleach                    6.1.0
# blessed                   1.20.0
# boltons                   24.1.0
# boto3                     1.26.130
# botocore                  1.29.130
# cachetools                4.2.4
# cellxgene-census          1.15.0
# certifi                   2023.5.7
# cffi                      1.17.1
# charset-normalizer        3.1.0
# chex                      0.1.86
# click                     8.1.3
# cloudpickle               3.1.0
# colorcet                  3.1.0
# colorlog                  6.8.2
# comm                      0.2.2
# contextlib2               21.6.0
# contourpy                 1.0.7
# croniter                  1.3.14
# cryptography              44.0.0
# cycler                    0.11.0
# Cython                    3.0.11
# dask                      2024.8.0
# dask-expr                 1.1.10
# dask-image                2024.5.3
# datashader                0.16.3
# dateutils                 0.6.12
# debugpy                   1.8.6
# decorator                 5.1.1
# decoupler                 1.8.0
# deepdiff                  6.3.0
# defusedxml                0.7.1
# demuxEM                   0.1.7.post1
# Deprecated                1.2.15
# dill                      0.3.9
# distributed               2024.8.0
# docker-pycreds            0.4.0
# docopt                    0.6.2
# docrep                    0.3.2
# einops                    0.8.0
# episcanpy                 0.4.0
# et_xmlfile                2.0.0
# etils                     1.5.2
# exceptiongroup            1.2.2
# executing                 2.1.0
# fa2_modified              0.3.10
# face                      24.0.0
# fastapi                   0.88.0
# fasteners                 0.19
# fastjsonschema            2.20.0
# fcsparser                 0.2.8
# filelock                  3.16.1
# flax                      0.8.5
# fonttools                 4.39.3
# fortran-language-server   1.12.0
# fqdn                      1.5.1
# frozenlist                1.3.3
# fsspec                    2023.5.0
# future                    1.0.0
# geopandas                 1.0.1
# get-annotations           0.1.2
# gitdb                     4.0.10
# GitPython                 3.1.31
# glom                      24.11.0
# google-auth               1.35.0
# google-auth-oauthlib      0.4.6
# greenlet                  3.1.1
# grpcio                    1.70.0
# h11                       0.14.0
# h5py                      3.4.0
# harmony-pytorch           0.1.8
# harmonypy                 0.0.10
# hnswlib                   0.8.0
# httpcore                  1.0.5
# httpx                     0.27.2
# humanize                  4.10.0
# idna                      3.4
# igraph                    0.11.6
# imageio                   2.36.1
# imbalanced-learn          0.12.3
# importlib_metadata        8.5.0
# importlib-resources       5.12.0
# inflect                   7.4.0
# inquirer                  3.1.3
# intervaltree              3.1.0
# ipykernel                 6.29.5
# ipython                   8.18.1
# isoduration               20.11.0
# itsdangerous              2.1.2
# jax                       0.4.30
# jax-cuda12-pjrt           0.4.30
# jax-cuda12-plugin         0.4.30
# jaxlib                    0.4.30
# jaxopt                    0.8.3
# jedi                      0.19.1
# Jinja2                    3.1.2
# jmespath                  1.0.1
# joblib                    1.2.0
# json5                     0.9.25
# jsonpointer               3.0.0
# jsonschema                4.23.0
# jsonschema-specifications 2023.12.1
# jupyter_client            8.6.3
# jupyter_core              5.7.2
# jupyter-events            0.10.0
# jupyter-lsp               2.2.5
# jupyter_server            2.14.2
# jupyter_server_terminals  0.5.3
# jupyterlab                4.2.5
# jupyterlab_pygments       0.3.0
# jupyterlab_server         2.27.3
# kiwisolver                1.4.4
# kneed                     0.8.5
# lazy_loader               0.4
# legacy-api-wrap           1.4
# leidenalg                 0.10.2
# Levenshtein               0.26.1
# lightgbm                  4.5.0
# lightning                 2.0.2
# lightning-cloud           0.5.34
# lightning-utilities       0.8.0
# llvmlite                  0.40.0
# locket                    1.0.0
# loompy                    3.0.8
# louvain                   0.8.2
# lxml                      5.3.0
# Mako                      1.3.5
# Markdown                  3.7
# markdown-it-py            2.2.0
# MarkupSafe                2.1.2
# matplotlib                3.7.1
# matplotlib-inline         0.1.7
# matplotlib-scalebar       0.8.1
# mdurl                     0.1.2
# mellon                    1.5.0
# mistune                   3.0.2
# ml_collections            0.1.1
# ml_dtypes                 0.5.0
# more-itertools            10.5.0
# mousipy                   0.1.6
# mpmath                    1.3.0
# msgpack                   1.1.0
# mudata                    0.2.4
# multidict                 6.0.4
# multipledispatch          1.0.0
# multiscale_spatial_image  1.0.1
# muon                      0.1.6
# natsort                   8.3.1
# nbclient                  0.10.0
# nbconvert                 7.16.4
# nbformat                  5.10.4
# nest-asyncio              1.6.0
# networkx                  3.1
# notebook_shim             0.2.4
# numba                     0.57.0
# numcodecs                 0.12.1
# numpy                     1.24.3
# numpy-groupies            0.11.2
# numpyro                   0.15.3
# nvidia-cublas-cu11        11.10.3.66
# nvidia-cublas-cu12        12.1.3.1
# nvidia-cuda-cupti-cu12    12.1.105
# nvidia-cuda-nvcc-cu12     12.6.68
# nvidia-cuda-nvrtc-cu11    11.7.99
# nvidia-cuda-nvrtc-cu12    12.1.105
# nvidia-cuda-runtime-cu11  11.7.99
# nvidia-cuda-runtime-cu12  12.1.105
# nvidia-cudnn-cu11         8.5.0.96
# nvidia-cudnn-cu12         9.1.0.70
# nvidia-cufft-cu12         11.0.2.54
# nvidia-curand-cu12        10.3.2.106
# nvidia-cusolver-cu12      11.4.5.107
# nvidia-cusparse-cu12      12.1.0.106
# nvidia-nccl-cu12          2.20.5
# nvidia-nvjitlink-cu12     12.6.68
# nvidia-nvtx-cu12          12.1.105
# oauthlib                  3.2.2
# ome-zarr                  0.9.0
# omnipath                  1.0.8
# openpyxl                  3.1.5
# opt_einsum                3.4.0
# optax                     0.2.3
# optuna                    4.0.0
# orbax-checkpoint          0.6.4
# ordered-set               4.1.0
# overrides                 7.7.0
# packaging                 23.1
# palantir                  1.3.6
# pandas                    2.0.1
# pandocfilters             1.5.1
# param                     2.1.1
# paramiko                  3.5.0
# parasail                  1.3.4
# parso                     0.8.4
# partd                     1.4.2
# pathtools                 0.1.2
# patsy                     0.5.3
# pegasus                   0.1.2
# pegasusio                 0.9.1
# pegasuspy                 1.10.0
# pexpect                   4.9.0
# Pillow                    9.5.0
# PIMS                      0.7
# pip                       24.2
# platformdirs              4.3.6
# plotly                    5.24.1
# pooch                     1.8.2
# progressbar2              4.5.0
# prometheus_client         0.21.0
# prompt_toolkit            3.0.48
# protobuf                  3.17.2
# psutil                    5.9.5
# ptyprocess                0.7.0
# pure_eval                 0.2.3
# pyarrow                   18.1.0
# pyarrow-hotfix            0.6
# pyasn1                    0.6.1
# pyasn1_modules            0.4.1
# pybind11                  2.13.6
# pycparser                 2.22
# pyct                      0.5.0
# pycurl                    7.45.4
# pydantic                  1.10.7
# pydot                     3.0.3
# pygam                     0.9.1
# Pygments                  2.15.1
# PyJWT                     2.6.0
# PyNaCl                    1.5.0
# pynndescent               0.5.10
# pyogrio                   0.10.0
# pyparsing                 3.0.9
# pypath_common             0.2.5
# pypath-omnipath           0.16.17
# pyproj                    3.6.1
# pyreadr                   0.5.2
# pyro-api                  0.1.2
# pyro-ppl                  1.9.1
# pysam                     0.22.1
# pysftp                    0.2.9
# PySide2                   5.15.2.1
# python-dateutil           2.8.2
# python-editor             1.0.4
# python-json-logger        2.0.7
# python-Levenshtein        0.26.1
# python-multipart          0.0.6
# python-utils              3.9.1
# pytorch-lightning         2.0.2
# pytorch-tabnet            4.0
# pytz                      2023.3
# PyYAML                    6.0
# pyzmq                     26.2.0
# RapidFuzz                 3.10.1
# rdata                     0.11.2
# readchar                  4.0.5
# referencing               0.35.1
# requests                  2.30.0
# requests-oauthlib         2.0.0
# rfc3339-validator         0.1.4
# rfc3986-validator         0.1.1
# rich                      13.3.5
# rpds-py                   0.20.0
# rsa                       4.9
# s3fs                      2023.6.0
# s3transfer                0.6.1
# scanpy                    1.9.3
# scgen                     2.1.1
# scib                      1.1.6
# scikit-image              0.24.0
# scikit-learn              1.2.2
# scikit-misc               0.3.1
# scipy                     1.10.1
# scirpy                    0.17.2
# scparadise                0.3.2b0
# scselpy                   1.1.7
# scsims                    3.0.6
# scvi-tools                1.1.6.post2
# seaborn                   0.12.2
# Send2Trash                1.8.3
# sentry-sdk                1.22.2
# session_info              1.0.0
# setproctitle              1.3.2
# setuptools                75.1.0
# setuptools-scm            8.1.0
# shap                      0.46.0
# shapely                   2.0.6
# shiboken2                 5.15.2.1
# six                       1.16.0
# slicer                    0.0.8
# slicerator                1.1.0
# smmap                     5.0.0
# sniffio                   1.3.0
# somacore                  1.0.11
# sortedcontainers          2.4.0
# soupsieve                 2.4.1
# spatial_image             1.1.0
# spatialdata               0.2.5.post0
# SQLAlchemy                2.0.35
# sqlparse                  0.5.3
# squarify                  0.4.4
# squidpy                   1.6.1
# stack-data                0.6.3
# starlette                 0.22.0
# starsessions              1.3.0
# statsmodels               0.14.0
# stdlib-list               0.8.0
# symphonypy                0.2.1
# sympy                     1.13.3
# tabulate                  0.9.0
# tbb                       2022.0.0
# tblib                     3.0.0
# tcmlib                    1.2.0
# tenacity                  9.0.0
# tensorboard               2.6.0
# tensorboard-data-server   0.6.1
# tensorboard-plugin-wit    1.8.1
# tensorstore               0.1.66
# terminado                 0.18.1
# texttable                 1.7.0
# threadpoolctl             3.1.0
# tifffile                  2024.8.30
# tiledb                    0.29.1
# tiledbsoma                1.11.4
# timeloop                  1.0.2
# tinycss2                  1.3.0
# toml                      0.10.2
# tomli                     2.0.1
# toolz                     0.12.1
# torch                     2.1.0+cu121
# torchaudio                2.1.0+cu121
# torchmetrics              0.11.4
# torchvision               0.16.0+cu121
# tornado                   6.4.1
# TOSICA                    1.0.0
# tqdm                      4.65.0
# traitlets                 5.9.0
# triton                    2.1.0
# typeguard                 4.4.1
# types-python-dateutil     2.9.0.20240906
# typing_extensions         4.5.0
# tzdata                    2023.3
# umap-learn                0.5.3
# uri-template              1.3.0
# urllib3                   1.26.15
# uvicorn                   0.22.0
# validators                0.34.0
# wandb                     0.15.2
# wcwidth                   0.2.6
# webcolors                 24.8.0
# webencodings              0.5.1
# websocket-client          1.5.1
# websockets                11.0.3
# Werkzeug                  3.1.3
# wget                      3.2
# wheel                     0.44.0
# wordcloud                 1.9.4
# wrapt                     1.17.0
# xarray                    2024.7.0
# xarray-dataclasses        1.8.0
# xarray-datatree           0.0.15
# xarray-schema             0.0.3
# xarray-spatial            0.4.0
# xlrd                      2.0.1
# XlsxWriter                3.2.2
# yamlordereddictloader     0.4.2
# yarl                      1.9.2
# zarr                      2.18.2
# zict                      3.0.0
# zipp                      3.21.0
# Note: you may need to restart the kernel to use updated packages.
